# %%
s = "string"
print(s, s[0], sep='\n')
# Out:
# string
# s

# %%
string = "동해물과 백두산이 마르고 닳도록"
print(string, type(string), sep='\n')
# Out:
# 동해물과 백두산이 마르고 닳도록
# <class 'str'>

# %%
text = "동해물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라만세\n 하느님이 보우하사 우리나라만세"
print(text)
# Out:
# 동해물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라만세
#  하느님이 보우하사 우리나라만세

# %%
text = '''1
2
3'''
print(text)
# Out:
# 1
# 2
# 3

# %%
s1 = "동해물과"
s2 = "백두산이"
s1+s2+s1
# Out:
# '동해물과백두산이동해물과'

# %%
s1 = "A"
print(s1 * 4)
# Out:
# AAAA

# %%
s = "string"
len(s)
# Out:
# 6

# %%
s ="BigDataCommunication"
print(s[0:10])
print(s[10:])
# Out:
# BigDataCom
# munication

# %%
s = "string"
s = s.capitalize()
print(s)
s = s.casefold()
print(s)
# Out:
# String
# string

# %%
s = "string"*2
print(s)
print(s.count('str'))
print(s.find('ing'))
print(s.rfind('ing'))
# Out:
# stringstring
# 2
# 3
# 9

# %%
s = "string"
print(' '.join(s))
print('?'.join(s))
# Out:
# s t r i n g
# s?t?r?i?n?g

# %%
s = "     string     "
print(s.strip())
print(s.rstrip())
print(s.lstrip())
# Out:
# string
#      string
# string

# %%
s = "string"
print(s.partition('r'))
print(s.partition('in'))
# Out:
# ('st', 'r', 'ing')
# ('str', 'in', 'g')

# %%
print(s.replace('r','R'))
# Out:
# stRing

# %%
print("1 2 3".split(' '))
print("1 2 3".replace(' ', '_').split('_'))
# Out:
# ['1', '2', '3']
# ['1', '2', '3']

# %%
pm = 34
if pm >= 35:
    print("나쁨")
elif 15 < pm <35:
    print("보통")
else:
    print("좋음")
# Out:
# 보통

# %%
pm = 88
if pm <= 35:
    if pm <= 15:
        print("좋음")
    else:
        print("보통")
else:
    if pm < 76:
        print("나쁨")
    else :
        print("매우나쁨")
# Out:
# 매우나쁨

# %%
list = ['un', 'deux', 'trois']

if 'un' in list:
    print("있다")
else:
    print("없다")
# Out:
# 있다

# %% [markdown]
# # **실습**

# %%
Age = 17 # Age < 20

if Age < 8 :
    print("학생 아님")
else:
    if 8 <= Age < 14 :
        print("초등학생")
    elif 14 <= Age < 17 :
        print("중학생")
    else:
        print("고등학생")
# Out:
# 고등학생
